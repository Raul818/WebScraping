# %%
import tweepy
from tweepy import OAuthHandler
from tweepy import Stream
from tweepy.streaming import StreamListener
import time
import json
import string
import re
from collections import Counter
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.tokenize import TweetTokenizer
from nltk.tokenize import casual, casual_tokenize
from nltk import bigrams

# %%
consumer_key = 'WxNCHN3AZKIbby85LE0FRn52h'
consumer_secret = 'sWuF83Pianv1Vm9R0txN34DROWFzJGpUZfQz673RytxhRRwEtL'
access_token = '975767174-qFHaY394JvFX8DbgKmq2cSQjsl1Cxhl1AuggDokq'
access_secret = '5eV3SHTA0HU7i7USSwxpspoqSk2sW6Ip7VBXqOgMLxsF9'

# %%
auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token,access_secret)
api = tweepy.API(auth)

# %%
#Reading Own Timeline
for status in tweepy.Cursor(api.home_timeline).items(2):
    print(status.text)
# Out:
# Taking stock of educational progress under Obama https://t.co/JNlgyT57wY https://t.co/U0GtcoISZy
# Amusingly it's a world where 2 people have all the understandings to just misunderstand each other.

# %%
#Reading own timeline-- JSON
for status in tweepy.Cursor(api.home_timeline).items(1):
    print(status._json)
# Out:
# {'lang': 'en', 'in_reply_to_status_id_str': None, 'extended_entities': {'media': [{'type': 'photo', 'id': 817322972520316929, 'id_str': '817322972520316929', 'sizes': {'large': {'w': 960, 'h': 640, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'small': {'w': 680, 'h': 453, 'resize': 'fit'}, 'medium': {'w': 960, 'h': 640, 'resize': 'fit'}}, 'indices': [73, 96], 'url': 'https://t.co/U0GtcoISZy', 'display_url': 'pic.twitter.com/U0GtcoISZy', 'media_url_https': 'https://pbs.twimg.com/media/C1e26cPXAAEU8jn.jpg', 'media_url': 'http://pbs.twimg.com/media/C1e26cPXAAEU8jn.jpg', 'expanded_url': 'https://twitter.com/TheAtlantic/status/817322974869123073/photo/1'}]}, 'source': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>', 'geo': None, 'in_reply_to_user_id': None, 'favorite_count': 0, 'text': 'Taking stock of educational progress under Obama https://t.co/JNlgyT57wY https://t.co/U0GtcoISZy', 'coordinates': None, 'in_reply_to_user_id_str': None, 'place': None, 'id_str': '817322974869123073', 'in_reply_to_screen_name': None, 'truncated': False, 'user': {'following': True, 'notifications': False, 'is_translator': False, 'protected': False, 'default_profile_image': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1268207868/twitter-icon-main_normal.png', 'friends_count': 1027, 'time_zone': 'Eastern Time (US & Canada)', 'followers_count': 1417582, 'profile_background_color': '000000', 'favourites_count': 666, 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1268207868/twitter-icon-main_normal.png', 'profile_sidebar_fill_color': 'E6ECF2', 'profile_link_color': '000000', 'description': 'Politics, culture, business, science, technology, health, education, global affairs, more. Tweets by @CaitlinFrazier', 'has_extended_profile': False, 'lang': 'en', 'profile_text_color': '000408', 'utc_offset': -18000, 'geo_enabled': False, 'listed_count': 26287, 'url': 'http://t.co/pI6FUBgQdl', 'profile_sidebar_border_color': 'BFBFBF', 'id_str': '35773039', 'profile_background_tile': False, 'created_at': 'Mon Apr 27 15:41:54 +0000 2009', 'profile_use_background_image': False, 'name': 'The Atlantic', 'id': 35773039, 'translator_type': 'none', 'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/215776367/twitter-main.jpg', 'location': 'Washington, D.C.', 'statuses_count': 103683, 'verified': True, 'screen_name': 'TheAtlantic', 'entities': {'description': {'urls': []}, 'url': {'urls': [{'display_url': 'theatlantic.com', 'url': 'http://t.co/pI6FUBgQdl', 'expanded_url': 'http://www.theatlantic.com', 'indices': [0, 22]}]}}, 'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/215776367/twitter-main.jpg', 'follow_request_sent': False, 'is_translation_enabled': True, 'contributors_enabled': False, 'default_profile': False}, 'contributors': None, 'created_at': 'Fri Jan 06 10:52:36 +0000 2017', 'possibly_sensitive': False, 'possibly_sensitive_appealable': False, 'id': 817322974869123073, 'retweet_count': 0, 'favorited': False, 'is_quote_status': False, 'entities': {'hashtags': [], 'media': [{'type': 'photo', 'id': 817322972520316929, 'id_str': '817322972520316929', 'sizes': {'large': {'w': 960, 'h': 640, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'small': {'w': 680, 'h': 453, 'resize': 'fit'}, 'medium': {'w': 960, 'h': 640, 'resize': 'fit'}}, 'indices': [73, 96], 'url': 'https://t.co/U0GtcoISZy', 'display_url': 'pic.twitter.com/U0GtcoISZy', 'media_url_https': 'https://pbs.twimg.com/media/C1e26cPXAAEU8jn.jpg', 'media_url': 'http://pbs.twimg.com/media/C1e26cPXAAEU8jn.jpg', 'expanded_url': 'https://twitter.com/TheAtlantic/status/817322974869123073/photo/1'}], 'user_mentions': [], 'urls': [{'display_url': 'theatln.tc/2iJCZ3c', 'url': 'https://t.co/JNlgyT57wY', 'expanded_url': 'http://theatln.tc/2iJCZ3c', 'indices': [49, 72]}], 'symbols': []}, 'retweeted': False, 'in_reply_to_status_id': None}

# %%
#Streaming (All the tweets with #Kaggle hashtag:

class MyListener(StreamListener):
    def __init__(self, time_limit=60):
        self.start_time = time.time()
        self.limit = time_limit
        self.saveFile = open('python.json', 'a')
        super(MyListener, self).__init__()

    def on_data(self, data):
        if (time.time() - self.start_time) < self.limit:
            self.saveFile.write(data)
            return True
        else:
            self.saveFile.close()
            return False

# %%
twitter_stream = Stream(auth, MyListener(time_limit = 30))
twitter_stream.filter(track=['Trump'])

# %%
#Body of a tweet-- Preprocessing
with open('python.json','r') as f:
    line = f.readline()
    tweet = json.loads(line)
    print (json.dumps(tweet, indent=3))
# Out:
# {
#    "lang": "es",
#    "in_reply_to_status_id_str": null,
#    "coordinates": null,
#    "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#    "geo": null,
#    "in_reply_to_user_id": null,
#    "favorite_count": 0,
#    "text": "RT @ReutersLatam: Brit\u00e1nica #May visitar\u00e1 a #Trump en Washington en la primavera boreal: comunicado https://t.co/1vNJ04MNrb https://t.co/Pl\u2026",
#    "in_reply_to_user_id_str": null,
#    "retweeted_status": {
#       "lang": "es",
#       "in_reply_to_status_id_str": null,
#       "coordinates": null,
#       "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#       "display_text_range": [
#          0,
#          105
#       ],
#       "in_reply_to_user_id": null,
#       "favorite_count": 3,
#       "text": "Brit\u00e1nica #May visitar\u00e1 a #Trump en Washington en la primavera boreal: comunicado https://t.co/1vNJ04MNrb https://t.co/PlUskzKXlt",
#       "in_reply_to_user_id_str": null,
#       "contributors": null,
#       "place": null,
#       "extended_entities": {
#          "media": [
#             {
#                "type": "photo",
#                "id": 817167908983828480,
#                "id_str": "817167908983828480",
#                "sizes": {
#                   "large": {
#                      "w": 450,
#                      "h": 299,
#                      "resize": "fit"
#                   },
#                   "thumb": {
#                      "w": 150,
#                      "h": 150,
#                      "resize": "crop"
#                   },
#                   "small": {
#                      "w": 450,
#                      "h": 299,
#                      "resize": "fit"
#                   },
#                   "medium": {
#                      "w": 450,
#                      "h": 299,
#                      "resize": "fit"
#                   }
#                },
#                "indices": [
#                   106,
#                   129
#                ],
#                "url": "https://t.co/PlUskzKXlt",
#                "display_url": "pic.twitter.com/PlUskzKXlt",
#                "media_url_https": "https://pbs.twimg.com/media/C1cp4jjUcAANu1Y.jpg",
#                "media_url": "http://pbs.twimg.com/media/C1cp4jjUcAANu1Y.jpg",
#                "expanded_url": "https://twitter.com/ReutersLatam/status/817167919675244544/photo/1"
#             }
#          ]
#       },
#       "in_reply_to_screen_name": null,
#       "truncated": false,
#       "user": {
#          "following": null,
#          "notifications": null,
#          "profile_image_url_https": "https://pbs.twimg.com/profile_images/646681894713561090/KxewqR-K_normal.png",
#          "is_translator": false,
#          "profile_banner_url": "https://pbs.twimg.com/profile_banners/201867844/1483625423",
#          "protected": false,
#          "default_profile_image": false,
#          "profile_image_url": "http://pbs.twimg.com/profile_images/646681894713561090/KxewqR-K_normal.png",
#          "friends_count": 394,
#          "time_zone": "Santiago",
#          "followers_count": 84840,
#          "profile_background_color": "444444",
#          "favourites_count": 10,
#          "profile_text_color": "000000",
#          "profile_sidebar_fill_color": "F5F5F5",
#          "profile_link_color": "3B94D9",
#          "description": "Cuenta oficial del servicio en espa\u00f1ol de Reuters para Am\u00e9rica Latina",
#          "lang": "es",
#          "utc_offset": -10800,
#          "geo_enabled": true,
#          "listed_count": 1896,
#          "url": "http://lta.reuters.com",
#          "profile_sidebar_border_color": "F5F5F5",
#          "id_str": "201867844",
#          "profile_background_tile": true,
#          "created_at": "Tue Oct 12 20:12:52 +0000 2010",
#          "profile_use_background_image": true,
#          "name": "Reuters Latam",
#          "id": 201867844,
#          "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/642068577797959680/QWk5GPSL.jpg",
#          "location": "Chile",
#          "statuses_count": 57832,
#          "verified": false,
#          "screen_name": "ReutersLatam",
#          "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/642068577797959680/QWk5GPSL.jpg",
#          "follow_request_sent": null,
#          "contributors_enabled": false,
#          "default_profile": false
#       },
#       "id_str": "817167919675244544",
#       "created_at": "Fri Jan 06 00:36:28 +0000 2017",
#       "possibly_sensitive": false,
#       "id": 817167919675244544,
#       "filter_level": "low",
#       "retweet_count": 6,
#       "favorited": false,
#       "is_quote_status": false,
#       "entities": {
#          "hashtags": [
#             {
#                "indices": [
#                   10,
#                   14
#                ],
#                "text": "May"
#             },
#             {
#                "indices": [
#                   26,
#                   32
#                ],
#                "text": "Trump"
#             }
#          ],
#          "media": [
#             {
#                "type": "photo",
#                "id": 817167908983828480,
#                "id_str": "817167908983828480",
#                "sizes": {
#                   "large": {
#                      "w": 450,
#                      "h": 299,
#                      "resize": "fit"
#                   },
#                   "thumb": {
#                      "w": 150,
#                      "h": 150,
#                      "resize": "crop"
#                   },
#                   "small": {
#                      "w": 450,
#                      "h": 299,
#                      "resize": "fit"
#                   },
#                   "medium": {
#                      "w": 450,
#                      "h": 299,
#                      "resize": "fit"
#                   }
#                },
#                "indices": [
#                   106,
#                   129
#                ],
#                "url": "https://t.co/PlUskzKXlt",
#                "display_url": "pic.twitter.com/PlUskzKXlt",
#                "media_url_https": "https://pbs.twimg.com/media/C1cp4jjUcAANu1Y.jpg",
#                "media_url": "http://pbs.twimg.com/media/C1cp4jjUcAANu1Y.jpg",
#                "expanded_url": "https://twitter.com/ReutersLatam/status/817167919675244544/photo/1"
#             }
#          ],
#          "user_mentions": [],
#          "symbols": [],
#          "urls": [
#             {
#                "display_url": "reut.rs/2iW0RAz",
#                "url": "https://t.co/1vNJ04MNrb",
#                "expanded_url": "http://reut.rs/2iW0RAz",
#                "indices": [
#                   82,
#                   105
#                ]
#             }
#          ]
#       },
#       "retweeted": false,
#       "geo": null,
#       "in_reply_to_status_id": null
#    },
#    "contributors": null,
#    "place": null,
#    "timestamp_ms": "1483700008828",
#    "in_reply_to_screen_name": null,
#    "truncated": false,
#    "user": {
#       "following": null,
#       "notifications": null,
#       "profile_image_url_https": "https://pbs.twimg.com/profile_images/749672816274870272/IAOeRVk1_normal.jpg",
#       "is_translator": false,
#       "profile_banner_url": "https://pbs.twimg.com/profile_banners/259338981/1479982365",
#       "protected": false,
#       "default_profile_image": false,
#       "profile_image_url": "http://pbs.twimg.com/profile_images/749672816274870272/IAOeRVk1_normal.jpg",
#       "friends_count": 3263,
#       "time_zone": "Indiana (East)",
#       "followers_count": 2179,
#       "profile_background_color": "131516",
#       "favourites_count": 988,
#       "profile_text_color": "333333",
#       "profile_sidebar_fill_color": "E899E8",
#       "profile_link_color": "700117",
#       "description": "Productor y periodista, facilitador de Video, me gusta el cine, la amistad, las palabras; fiz R\u00e1dio e TV na ECA-USP, creo en la paz, pero en la guerra tambi\u00e9n",
#       "lang": "es",
#       "utc_offset": -18000,
#       "geo_enabled": true,
#       "listed_count": 88,
#       "url": "http://xcu2008.wix.com/profesor-mario-2013",
#       "profile_sidebar_border_color": "820E82",
#       "id_str": "259338981",
#       "profile_background_tile": false,
#       "created_at": "Tue Mar 01 17:22:12 +0000 2011",
#       "profile_use_background_image": true,
#       "name": "Prof Mario Rodriguez",
#       "id": 259338981,
#       "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/214067762/DSC07153.JPG",
#       "location": "Rep\u00fablica de Panam\u00e1",
#       "statuses_count": 51626,
#       "verified": false,
#       "screen_name": "ProfMrmistery",
#       "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/214067762/DSC07153.JPG",
#       "follow_request_sent": null,
#       "contributors_enabled": false,
#       "default_profile": false
#    },
#    "id_str": "817323192285069312",
#    "created_at": "Fri Jan 06 10:53:28 +0000 2017",
#    "possibly_sensitive": false,
#    "id": 817323192285069312,
#    "filter_level": "low",
#    "retweet_count": 0,
#    "favorited": false,
#    "is_quote_status": false,
#    "entities": {
#       "hashtags": [
#          {
#             "indices": [
#                28,
#                32
#             ],
#             "text": "May"
#          },
#          {
#             "indices": [
#                44,
#                50
#             ],
#             "text": "Trump"
#          }
#       ],
#       "user_mentions": [
#          {
#             "screen_name": "ReutersLatam",
#             "id_str": "201867844",
#             "id": 201867844,
#             "indices": [
#                3,
#                16
#             ],
#             "name": "Reuters Latam"
#          }
#       ],
#       "symbols": [],
#       "urls": [
#          {
#             "display_url": "reut.rs/2iW0RAz",
#             "url": "https://t.co/1vNJ04MNrb",
#             "expanded_url": "http://reut.rs/2iW0RAz",
#             "indices": [
#                100,
#                123
#             ]
#          }
#       ]
#    },
#    "retweeted": false,
#    "in_reply_to_status_id": null
# }

# %%
tweet = 'RT @marcobonzanini: just an example! :D http://example.com #NLP'
tk = TweetTokenizer()
tk.tokenize(tweet)
# Out:
# ['RT',
#  '@marcobonzanini',
#  ':',
#  'just',
#  'an',
#  'example',
#  '!',
#  ':D',
#  'http://example.com',
#  '#NLP']

# %%
with open('python.json','r') as f:
    for line in f:
        tweet = json.loads(line)
        print (tk.tokenize(tweet['text']))
# Out:
# ['RT', '@ReutersLatam', ':', 'Británica', '#May', 'visitará', 'a', '#Trump', 'en', 'Washington', 'en', 'la', 'primavera', 'boreal', ':', 'comunicado', 'https://t.co/1vNJ04MNrb', 'https://t.co/Pl…']
# ['Brilliant', 'https://t.co/5CNFQM78Tu']
# ['@sparrowmedia', '@benfowlkesMMA', 'I', 'hope', 'Trump', 'ships', 'out', 'Democratic', 'Liberals', 'along', 'with', 'Illegals', '!', 'Nothing', 'But', 'Hypocrites', '!']
# ['@GloomandDoom1', 'DELETE', 'TRUMP', 'DELETE', 'DELETE', 'DELETE']
# ['@realDonaldTrump', 'Thank', 'u', 'Jesus', 'for', 'President', 'Trump', 'https://t.co/2VnpKHNVvO']
# ['RT', '@ShontiMF', ':', "Y'all", 'gon', 'pass', 'out', '&', 'wake', 'up', 'on', 'a', 'boat', '.', 'https://t.co/hO9yu4pkWa']
# ['RT', '@haaretzcom', ':', 'Remember', 'Jewish', 'firebrand', 'Meir', 'Kahane', '?', 'Buoyed', 'by', 'Trump', 'his', 'followers', 'are', 'looking', 'to', 'revive', 'the', 'movement', 'https://t.co/Q0PNU…']
# ['RT', '@NadelParis', ':', 'WE', 'CAN', '#IMPEACH', 'trump', '!', 'Stop', '#Russians', '#Putin', '#Resist', '#TheResistance', 'We', "can't", 'let', '#PutinsPuppet', 'become', 'the', 'most', 'powe', '…']
# ['Rosie', "O'Donnell", ':', '"', 'We', 'have', '3', 'weeks', 'to', 'stop', 'mentally', 'unstable', 'Trump', '"', 'https://t.co/VO5FSRZqiu', '#', 'via', '@HuffPostEnt']
# ['RT', '@voxdotcom', ':', 'Trump', 'has', 'been', 'slamming', 'US', 'intel', 'agencies', '.', 'They', 'just', 'fired', 'back', '.', 'https://t.co/ZyWr1i8tmS']
# ['RT', '@cnnbrk', ':', 'Trump', 'lets', 'Mexico', 'off', 'the', 'hook', '?', 'House', 'GOP', 'officials', 'say', 'Trump', 'will', 'ask', 'Congress', 'to', 'pay', 'for', 'building', 'the', 'wall', '.', 'https://t.co/bRA4…']
# ['Semua', 'Diplomat', 'AS', 'Era', 'Obama', 'Akhiri', 'Jabatan', 'Saat', 'Trump', 'Dilantik', 'https://t.co/WpmtYhPnzr', 'https://t.co/fLjE4VIEsL']
# ['RT', '@immigrant4trump', ':', '.', '@JesseBWatters', 'Gets', 'His', 'Own', 'Weekly', 'Show', 'On', 'Fox', 'News', '#Maga', '#WattersWorld', '#Trump', 'https://t.co/fMSEuq5BRP']
# ['RT', '@CNN', ':', 'Sources', ':', 'President-elect', 'Donald', 'Trump', 'will', 'ask', 'Congress', ',', 'not', 'Mexico', ',', 'to', 'pay', 'for', 'border', 'wall', 'https://t.co/6NpVBHUpnq', 'https://t.co/t…']
# ['RT', '@Alyssa_Milano', ':', 'Uh', 'oh', ',', '@realDonaldTrump', '.', 'https://t.co/I4XITzjdr3']
# ['RT', '@Salon', ':', 'Democrats', 'saying', '“', 'Donald', 'Trump', 'wants', 'to', 'make', 'America', 'sick', 'again', '”', 'really', 'got', 'under', 'Trump', '’', 's', 'skin', 'https://t.co/igcoZJF3Sb']
# ['RT', '@mistakrass', ':', '20', 'Minuten', '-', 'Obama', 'ist', 'auf', '«', 'F', '*', 'ck-You-Tournee', '»', 'gegen', 'Trump', '-', 'News', 'https://t.co/y6VnxsEOIG', 'via', '@20min']
# ['RT', '@CallawayBOT', ':', '2', 'House', 'Democrats', 'boycott', 'inauguration', 'over', 'Trump', 'comments', 'https://t.co/RACbFJHjYX', '#ResistTrump']
# ["Here's", 'the', 'latest', 'CrossTalk', 'production', ':', 'Targeting', 'Russia', 'https://t.co/TxGtlUyS6x']
# ['RT', '@NewtTrump', ':', 'RETWEET', 'if', 'you', 'agree', 'with', 'Newt', ':', '"', 'Trump', 'will', 'make', '(', 'almost', ')', 'all', 'of', 'America', 'happy', 'if', 'he', 'can', 'get', 'our', 'economy', 'moving', '.', '"', 'https://t.…']
# ['Trump', 'breaks', 'promise', 'to', 'reveal', 'secret', 'intel', 'on', 'Russian', 'hacking', 'by', 'Wednesday', 'https://t.co/5EUhzS7emU']
# ['RT', '@Toussaint_Chen', ':', '#NiggerNavy', 'When', 'trump', 'want', 'you', 'to', 'fight', 'ISIS', 'but', 'no', 'terrorist', 'ever', 'called', 'you', 'a', 'nigger', 'https://t.co/ksuqbiTjJi']
# ['RT', '@Kasparov63', ':', 'Yes', ',', 'if', 'you', 'read', 'the', 'Russian', 'propaganda', 'you', 'can', 'predict', 'what', 'Trump', 'will', 'tweet', 'next', 'with', 'uncanny', 'accuracy', '.', 'https://t.co/rpzr…']
# ['Chinese', 'State', 'Media', 'Threatens', 'Trump', 'With', "'", 'Big', 'Sticks', "'", 'If', 'He', 'Pushes', 'For', 'A', 'Trade', 'War', '-', 'https://t.co/5QzFMGCaiq', 'via', 'https://t.co/NbeZuRj9Gy']
# ['RT', '@charliekirk11', ':', 'Senate', 'votes', '51-48', 'to', 'repeal', 'Obamacare', 'Good', 'start', '.', "Can't", 'wait', 'for', 'Trump', 'to', 'finish', 'it', 'Jan', '20', '!']
# ['RT', '@DebAlwaystrump', ':', 'OBSTRUCTIONIST', 'HEAD', 'CLOWN', 'SCHUMER', 'Schumer', '2', 'Trump', 'You', 'better', 'do', 'what', 'Democrats', 'want', 'or', 'else', '😠', 'Trump', '2', 'Schumer', 'NO', '!', '!', '…']
# ['RT', '@Anna_LaPierre', ':', 'Let', 'Trump', 'see', 'what', 'he', 'wants', '.', 'I', 'see', 'this', '.', '#ObamaYears', '#MyAmerica', '@Potus', 'https://t.co/NPsDAez704']
# ['RT', '@_Proud_American', ':', 'VIDEO', ':', "CNN's", 'Don', 'Lemon', 'Says', 'Torture', 'of', 'Special', 'Needs', 'white', 'man', 'by', '4', 'Anti-Trump', 'Blacks', 'is', 'just', '"', 'Bad', 'Home', 'Training', '"', 'ht', '…']
# ['RT', '@Aleks_weltweit', ':', 'Bock', 'zum', 'Gärtner', ':', '"', 'Trump', 'macht', 'Wall-Street-Anwalt', 'zum', 'Chef', 'der', 'Börsenaufsicht', '"', 'https://t.co/SEB2nElkQV']
# ['#Trump', 'was', 'taken', 'by', 'Mephistopheles', 'long', 'ago', '&', 'serves', 'only', 'the', 'devil', 'and', 'will', 'burn', 'the', 'world', 'down', '.', '@realDonaldTrump', 'https://t.co/8ucOsyeSa1']
# ['RT', '@haaretzcom', ':', 'Remember', 'Jewish', 'firebrand', 'Meir', 'Kahane', '?', 'Buoyed', 'by', 'Trump', 'his', 'followers', 'are', 'looking', 'to', 'revive', 'the', 'movement', 'https://t.co/Q0PNU…']
# ['no', 'real', 'surprise', 'to', 'anyone', 'is', '?', '@realDonaldTrump', "'", 's', 'reaction', 'going', 'to', 'be', '"', 'that', 'makes', 'me', 'SMART', '!', '"', '?', '?', 'https://t.co/WQrFMdmA06']
# ["'", 'Grow', 'Up', ',', "'", 'Says', 'US', 'Vice', 'President', 'Joe', 'Biden', 'To', 'President-Elect', 'Donald', 'Trump', 'https://t.co/FiRECR3Qph']
# ['RT', '@Fort', ':', 'She', 'waited', 'her', 'entire', 'life', 'for', 'a', 'female', 'president', '.', "She's", 'the', 'representation', 'of', 'how', 'America', 'feels', 'now', 'that', 'Trump', 'has', '…']
# ['RT', '@ActualidadRT', ':', 'No', 'necesita', 'un', 'muro', ':', 'los', 'tuits', 'de', 'Trump', 'alcanzan', 'para', 'minar', 'la', 'economía', 'mexicana', 'https://t.co/hBgQEhEc27', 'https://t.co/wgS…']
# ['RT', '@NancySinatra', ':', 'He', 'would', 'never', 'support', 'a', 'bigot', '.', 'https://t.co/lVECmwNnDz']
# ['RT', ':', 'nytimes', ':D', 'onald', 'Trump', 'appears', 'to', 'be', 'seething', 'ahead', 'of', 'his', 'intelligence', 'briefing', 'on', 'Russian', 'election', 'meddling', 'https://t.co/tXej5ObBpc']
# ['RT', '@ShontiMF', ':', "Y'all", 'gon', 'pass', 'out', '&', 'wake', 'up', 'on', 'a', 'boat', '.', 'https://t.co/hO9yu4pkWa']
# ['@teuutiset', 'tämä', 'tietenkin', 'skipataan', 'koska', 'trump', 'on', 'rasistifasistinatsi', '😕']
# ['@glttat', '@henrivedas', 'Si', 'Poutine', 'et', 'Trump', "s'entendent", 'sur', 'le', 'dos', 'des', 'mondialistes', 'européens', 'on', 'va', 'bien', 'rire', 'hihi']
# ['RT', '@JonRiley7', ':', 'Trump', 'is', 'anti-elitist', 'but', 'his', 'cabinet', 'is', 'full', 'of', 'billionaires', '?', 'Turns', 'out', '"', 'elite', '"', 'just', 'means', '"', 'knows', 'what', "they're", 'doi', '…']
# ['RT', '@JesseLehrich', ':', "you're", 'quite', 'literally', 'the', 'single', 'least', 'credible', 'person', 'in', 'history', 'to', 'make', 'this', 'argument', '.', 'https://t.co/CqG7Umwu0D']
# ['RT', '@ezlusztig', ':', 'Here', 'is', 'just', 'one', 'example', 'of', 'the', 'kind', 'of', 'pointless', 'misery', 'Trump', 'has', 'just', 'imposed', 'on', 'our', 'diplomatic', 'staff', 'all', 'over', 'th', '…']
# ['Donald', 'Trump', 'Blasts', '‘', 'Head', 'Clown', '’', 'Chuck', 'Schumer', 'For', 'Blocking', 'Obamacare', 'Replacement', '-', 'Breitbart', 'https://t.co/73HkqHYrLj']
# ['RT', '@USAforTrump2016', ':', 'One', 'of', 'our', 'own', 'is', 'being', 'attacked', '!', '@robertscott3', 'was', 'state', 'director', 'of', 'the', 'Ohio', 'Trump', 'campaign', ';', 'did', 'incredible', 'work', '!', 'ht', '…']
# ['California', 'Farmers', 'Fret', 'Over', 'Labor', 'Shortages', 'As', 'Trump', 'Vows', 'To', 'Deport', 'Their', 'Work', 'Force', '-', 'https://t.co/7GejNXad2R', 'https://t.co/sSkIBneeeh']
# ['RT', '@sckiwireddevil', ':', 'All', 'the', 'little', 'NAZIS', 'standing', 'in', 'a', 'row', ',', '3', 'wearing', 'swastikas', ',', '1', 'wearing', 'a', 'bow', '.', 'https://t.co/LJP09zaalX']
# ['RT', '@spectatorindex', ':', 'BREAKING', ':', "Trump's", 'team', 'has', 'asked', 'Congressional', 'leaders', 'to', 'fund', 'border', 'wall', 'with', 'Mexico']
# ['México', ':', '"', 'Peña', 'Nieto', 'carece', 'de', 'un', 'plan', 'integral', 'para', 'enfrentar', 'a', 'Trump', '"', 'https://t.co/pUPQcyIHQW']
# ['RT', '@mooshakins', ':', 'They', 'have', 'to', 'pass', 'it', 'before', 'you', 'can', 'see', "what's", 'in', 'it', '.', 'https://t.co/MwrT8l5PMa']
# ['RT', '@JayS2629', ':', "You're", 'fired', '!', 'Trump', 'Fires', 'All', 'Obama', 'Politically', 'Appointed', 'Ambassadors', 'Effective', 'Inauguration', 'Day', 'https://t.co/i7QxlL8je8']
# ['Just', 'ask', 'Donald', 'J', '.', 'Trump', '.', 'He', "didn't", 'reveal', 'his', 'income', 'tax', 'returns', ',', 'but', 'his', 'birth', 'certificate', 'is', 'not', 'questioned', '!']
# ['Biden', 'says', 'Trump', 'should', '"', 'grow', 'up', '"', 'https://t.co/Uyr5xzqpBo']
# ['RT', '@FrankConniff', ':', 'Trump', 'asking', 'Congress', ',', 'not', 'Mexico', ',', 'to', 'fund', 'the', 'wall', '.', 'Must', 'admit', ',', "he's", 'way', 'better', 'at', 'telling', 'his', 'supporters', 'to', 'go', 'fuck', 'the', '…']
# ['@izakaminska', '@crookedfootball', 'I', 'am', 'not', 'even', 'close', 'to', 'pejorative', 'enough', 'for', 'Trump', '.']
# ['@IamRitaAnne', '@TheShaunNavarro', "it's", 'funny', 'trump', 'supporters', 'say', 'obama', 'created', 'no', 'jobs', 'yet', "you're", 'happy', 'to', 'go', 'to', 'yours', 'in', 'his', '"', 'awful', '"', 'economy', '🤔']
# ['Retweeted', 'Nancy', 'Sinatra', '(', '@NancySinatra', '):', 'He', 'would', 'never', 'support', 'a', 'bigot', '.', 'https://t.co/jbhXYo4QxP', 'https://t.co/DMDXQPYF1n']
# ['RT', '@Reuters', ':', 'Trump', 'is', 'ordering', 'all', 'ambassadors', 'appointed', 'by', 'Obama', 'to', 'leave', 'their', 'post', 'by', 'inauguration', 'day', ':', '…']
# ['Can', 'Trump', 'convince', '#Toyota', 'to', 'build', 'their', 'new', '$', '1B', 'auto', 'plant', 'in', 'the', 'US', 'instead', 'of', '#Mexico', '?', '!', '#MAGA', '🇺', '🇸', '🙌', 'https://t.co/5inZDbd40m', '#tcot', '#news']
# ['RT', '@ananavarro', ':', 'Remember', 'the', 'chants', 'at', 'Trump', 'rallies', '?', 'Trump', ':', '"', "Who's", 'gonna', 'pay', 'for', 'the', 'wall', '?', '"', 'Crowd', ':', '"', 'Mexico', '!', '!', '"', 'Real', 'answer', "should'v", '…']
# ['And', ',', 'oh', ',', 'just', 'by', 'the', 'way', ',', 'Woolsey', 'has', 'been', 'an', 'extreme', 'warmonger', '-', 'but', 'even', 'he', 'is', '"', 'too', 'stable', '"', 'for', "Trump's", 'administr', '…', 'https://t.co/weYVCh3P5a']
# ['Après', 'Ford', 'et', 'General', 'Motors', ',', 'Toyota', 'se', 'fait', 'tancer', 'par', 'Donald', 'Trump', 'https://t.co/9JFHMwweAA']
# ['RT', '@OnlineMagazin', ':', '🆘', '‼', '️', '😂', 'Haha', '!', 'When', 'Donald', '#Trump', 'Is', 'taking', 'America', 'back', 'from', '#Obama', '!', '(', 'Troy', 'Movie', 'Parody', ')', 'https://t.co/JoliNWLPdT']
# ['RT', '@RawStory', ':', 'Bombshell', 'report', 'claims', 'at', 'least', '50', 'Trump', 'electors', 'are', 'illegitimate', '—', 'and', 'should', 'not', 'have', 'voted', '…']
# ['RT', '@nytimes', ':', "Trump's", 'transition', 'staff', 'has', 'ordered', 'politically', 'appointed', 'ambassadors', 'to', 'leave', 'their', 'posts', 'by', 'Inauguration', 'Day', 'https://t.co/L…']
# ['RT', '@thehill', ':', 'Contractor', 'says', 'Trump', 'owes', 'him', 'millions', 'for', 'work', 'at', 'D', '.', 'C', '.', 'hotel', 'https://t.co/CGw5ad8Cis', 'https://t.co/7XzRuTYxaj']
# ['@Morning_Joe', 'Trump', 'has', 'cast', 'a', 'shadow', 'over', 'r', 'election', '.', 'A', 'liar', 'cheat', ',', 'thief', ',', 'a', 'clown', ',', 'a', 'joke', "who's", 'not', 'in', 'office', 'but', 'has', 'lowered', 'r', 'world', 'standing']
# ['RT', '@FoxNews', ':', 'Biden', 'says', 'Trump', 'should', '"', 'grow', 'up', '"', 'https://t.co/KnNjDvuahz']
# ['Could', 'the', 'numbers', 'of', 'those', 'actually', 'believing', 'Assange', 'be', 'overestimated', 'and', 'debating', 'his', 'veracity', 'be', 'a', 'distraction', 't', '…', 'https://t.co/e10Z07vXpr']
# ['RT', '@TheHighFessions', ':', 'Forget', 'Trump', '&', 'Hillary', '.', 'This', 'dude', 'Gary', 'Johnson', 'lit', 'fam', '🔥', '🔥', 'https://t.co/DqLMuk5oAK']
# ['RT', '@KaraCalavera', ':', 'So', 'what', "you're", 'saying', 'here', 'is', 'that', "we're", 'all', 'going', 'to', 'die', 'in', 'the', 'next', 'four', 'years', '?', "'", 'Cause', "that's", 'what', "I'm", 'hearing', '.', 'https', ':/', '…']
# ['RT', '@ADRIANAAZZIAS', ':', 'Que', 'panorama', '¡', 'Trump', 'se', 'une', 'con', 'Rusia', 'e', 'Israel', 'y', 'atrás', 'los', 'chinos', 'contra', 'el', 'Islamismo', 'y', 'el', 'burro', 'coloca', 'a', 'un', 'musulmán', 'en', '…']
# ['RT', '@WayneDupreeShow', ':', '"', 'Kerosene', '"', 'Maxine', 'Waters', 'says', 'she', "doesn't", 'want', '2', 'work', 'with', 'Donald', 'Trump', 'oh', 'wait', ',', 'President-elect', 'said', 'he', 'wanted', 'to', 'br', '…']
# ['RT', '@ish10040', ':', 'BREAKING', ':', 'Piers', 'Morgan', 'Disgusted', 'by', 'Lack', 'of', 'Media', 'Outrage', 'Over', 'Anti-Trump', 'Kidnapping', '/', 'Hate', 'Crime', 'https://t.co/TtRyfRnvPW', 'gt']
# ['RT', '@Prime_Politics_', ':', 'Former', 'CIA', 'Director', 'James', 'Woolsey', 'Quits', 'Trump', 'Transition', 'Team', 'READ', ':', 'https://t.co/0mZsILsgpu', '#tcot', '#P2']
# ['O', 'congresso', 'americano', 'têm', 'que', 'ficar', 'calado', 'e', 'apoiar', 'o', 'Trump', '...', 'ou', 'eles', 'perdem', 'a', 'credibilidade', '...']
# ['UPDATE', ':', 'Former', 'CIA', 'chief', 'cuts', 'ties', 'with', 'Trump', 'https://t.co/RXVxbLLLOD']
# ['1', '.', 'Main', 'points', 'from', '@TheEconomist', '"', 'Mr', 'Trump', 'should', 'maintain', 'at', 'least', 'current', 'level', 'of', 'air', 'support', ',', 'training', 'and', 'funding', 'for', 'the', 'Afghan', 'army', '"']
# ['Joe', 'Biden', 'amtaka', 'Trump', 'kujitambua', 'https://t.co/qJvyKc1ipt', 'https://t.co/okorwEJZUa']
# ['@usndan505', '@hotfunkytown', '@thehill', 'Trump', 'fawns', 'all', 'over', 'Putin', 'like', 'a', 'schoolgirl', '.']
# ['RT', '@wikileaks', ':', 'Result', 'of', 'CIA', 'officials', 'secretly', 'feeding', 'press', 'to', 'harm', 'Trump', ':', 'NBC', 'poll', ':', 'CIA', 'net', 'favorability', 'Trump', 'voters', ':', '+', '2', 'Clinton', 'voter', '…']
# ['RT', '@NYMag', ':', 'Trump', 'preps', 'for', 'briefing', 'on', 'Russian', 'hacking', 'by', 'going', 'after', 'U', '.', 'S', '.', 'intelligence', 'agencies', ':', 'https://t.co/AaJk41dO32', 'https://t.co/k7F9…']
# ['Countering', '#Trump', ',', 'Bipartisan', 'Voices', 'Strongly', 'Affirm', 'Findings', 'on', 'Russian', 'Hacking', ',', 'via', '@nytimes', '#russianhacking', 'https://t.co/Ax9tQ5RevM']
# ['RT', '@CNN', ':', 'Former', 'CIA', 'chief', 'cuts', 'ties', 'with', 'Trump', 'https://t.co/Vp4ZmXD2Yg', 'https://t.co/Jjch7uZFO1']
# ['RT', '@paulbuitink', ':', 'It', '’', 's', 'a', 'matter', 'of', 'time', 'before', 'Trump', 'tweets', 'about', '#bitcoin', 'to', 'impose', 'a', 'border', 'tax', ',', 'call', 'on', 'miners', 'to', 'come', 'home', 'and', 'increase', '…']
# ['RT', '@SenSanders', ':', 'Millions', 'of', 'people', 'voted', 'for', 'Mr', '.', 'Trump', 'believing', 'that', 'he', 'would', 'keep', 'his', 'word', 'and', 'not', 'cut', 'Social', 'Security', ',', 'Medicare', '…']
# ['RT', '@Jason_Pollock', ':', 'This', 'is', 'INSANE', '.', 'The', '2016', 'election', 'was', 'such', 'a', 'crime', '.', 'Our', 'democracy', 'has', 'been', 'stolen', '.', 'Are', 'you', 'ready', 'to', 'fight', 'this', '?', 'https://…']
# ['RT', '@sarahkendzior', ':', 'As', 'recently', 'as', 'March', ',', 'Cruz', 'pushed', 'back', 'hard', 'on', "Trump's", 'ties', 'to', 'Russia', 'and', 'the', 'dangers', 'of', "Putin's", 'regime', '…']
# ['RT', '@ggreenwald', ':', 'Note', 'how', 'Sanders', 'is', 'going', 'after', 'Trump', 'on', 'what', 'voters', 'care', 'about', '-', 'SS', '&', 'Medicare', '-', 'rather', 'than', 'ranting', 'about', 'Putin', '&', '…']
# ['RT', '@paulkrugman', ':', 'People', 'say', 'Trump', 'only', 'chooses', 'people', 'w', '/', 'huge', 'conflicts', 'of', 'interest', '.', 'Not', 'so', ',', 'also', 'people', 'who', 'r', 'always', 'wrong', '1', '/', 'https://t.c…']
# ['RT', '@PositiveNewsUK', ':', '“', 'Global', 'energy', 'transition', 'is', 'progressing', 'faster', 'than', 'many', 'think', ',', 'and', 'is', 'probably', 'irreversible', '”', 'says', '@JeremyLeggett', 'http', '…']
# ["#Trump's", 'opening', 'to', '#torture', 'may', 'have', 'a', 'domino', 'effect', 'on', 'other', 'fragile', 'regimes', 'around', 'the', 'world', '.', 'https://t.co/Du1tWUD6dg']
# ['RT', '@Ish_Bhandari', ':', 'Will', 'there', 'be', 'Libtard', 'cry', 'of', '"', 'Intolerant', '"', 'like', 'in', 'India', '?', 'https://t.co/KTIANjEVln']
# ['RT', '@NewtTrump', ':', 'The', 'fact', 'is', 'that', 'when', 'it', 'mattered', ',', 'key', 'voters', 'in', 'WI', ',', 'MI', ',', 'and', 'PA', 'said', '"', 'I', "don't", 'want', 'Hillary', 'Clinton', '"', 'and', 'voted', 'Trump', '.', 'https', ':/', '…']
# ['RT', '@SocialWiz', ':', 'Can', 'Donald', 'Trump', 'save', 'Twitter', '?', '"', "It's", 'like', 'owning', 'your', 'own', 'newspaper-without', 'the', 'losses', '"', '@realDonaldTrump', '😎', '👍', '🏻', '…']
# ['RT', '@TrumpFrance', ':', 'Torture', ',', 'haine', 'de', 'Trump', 'et', 'racisme', 'anti-blanc', 'à', '#Chicago', '.', 'Voici', 'les', 'inculpés', ':', 'https://t.co/2k14tRHSVg']
# ['@Freeyourmindkid', 'got', 'my', 'pay', 'increase', 'starts', 'first', 'week', 'of', 'February', '...', 'Still', 'glad', 'I', 'voted', 'for', 'trump', '...']
# ['RT', '@NadelParis', ':', 'WE', 'CAN', '#IMPEACH', 'trump', '!', 'Stop', '#Russians', '#Putin', '#Resist', '#TheResistance', 'We', "can't", 'let', '#PutinsPuppet', 'become', 'the', 'most', 'powe', '…']
# ['RT', '@MinModulation', ':', 'Trump', 'Wants', 'a', 'Much', 'Faggier', 'Navy', ':', "Here's", 'How', 'Much', "It'll", 'Cost', 'https://t.co/lW4255JkRD']
# ['peine', 'méritée', ':', 'guillotine', 'quel', 'que', 'soit', 'leur', 'âge', '!', 'ça', 'viendra', 'un', 'jour', 'ça', 'viendra', '!', '!', 'https://t.co/ov2GMdK3qd']
# ['RT', '@JuddLegum', ':', 'Trump', '"', 'saved', '"', '700', 'jobs', 'at', 'Carrier', '.', 'His', 'plan', 'to', 'repeal', 'Obamacare', 'would', 'kill', '3', 'MILLION', 'jobs', '.', '…']
# ['RT', '@TrumpSuperPAC', ':', 'Big', '&', 'Rich', 'to', 'Perform', 'at', '#TRUMP', 'Inauguration', 'Gala', '!', '#MAGA', 'https://t.co/fo9yfwWjBj']
# ['RT', '@CarolineWalkerB', ':', '2,000', ',', '000', 'bikers', 'announce', 'their', 'intentions', 'for', 'Trump', '’', 's', 'inauguration', 'to', 'protect', 'him', 'from', 'left', 'wing', 'lunatics', '–', 'YOU', '…', '…']
# ['RT', '@DPRK_News', ':', 'Orange-Faced', 'Freak', 'Donald', 'Trump', 'to', 'ask', 'US', 'parliament', 'for', 'funds', 'to', 'build', 'Mexican', 'wall', ',', 'in', 'shameful', 'admission', 'of', 'onanistic', 'imp', '…']
# ['RT', '@DavidKlion', ':', 'You', 'have', 'every', 'right', 'to', 'hate', 'the', 'CIA', '.', 'You', 'still', "don't", 'want', 'it', 'purged', 'and', 'run', 'by', 'Trump', 'loyalists', '.', 'This', 'is', 'how', 'dictatorships', '…']
# ['RT', '@ResistanceParty', ':', 'https://t.co/ZPo5betC0y']
# ['RT', '@politico', ':', 'New', 'pro-Trump', 'political', 'group', 'readies', 'for', 'launch', 'https://t.co/myd6aTNKx7', 'via', '@ShaneGoldmacher', '&', '@PoliticoAlex', 'https://t.co/o1…']
# ['RT', '@lemonde_inter', ':', 'Après', 'Ford', 'et', 'General', 'Motors', ',', 'Toyota', 'se', 'fait', 'tancer', 'par', 'Donald', 'Trump', '-', 'par', '@StephaneLauer', 'https://t.co/RR98Xian2v']
# ['RT', '@etraditionalist', ':', 'Mainstream', '#FakeNews', 'is', 'now', 'calling', "#Wikileaks's", '#JulianAssange', 'a', '"', '#US', 'foe', '"', 'and', 'slandering', '#Trump', 'for', 'backing', 'him', '…']
# ['Pulling', 'out', 'all', 'US', 'ambassadors', 'makes', 'sense', ',', 'since', 'Trump', 'is', 'fairly', 'well', 'representated', 'by', "Putin's", 'embassies', 'https://t.co/2unOTxV3Sm']
# ['RT', '@KlayVolk', ':', 'Donald', 'Trump', 'Fires', 'Barack', 'Obama', '!', 'https://t.co/RxTH5UEaqm']
# ['RT', '@GartrellLinda', ':', 'Black', '&', 'Decker', 'Announce', 'Opening', 'of', 'New', 'U', '.', 'S', '.', 'Plant', 'After', 'Trump', 'White', 'House', 'Win', 'https://t.co/LaLy9IKQR6', 'Pro', 'business', 'envir', '…']
# ['RT', '@abcbourse', ':', 'Face', 'à', 'Trump', ',', 'Toyota', 'et', 'consorts', 'dégainent', 'les', 'preuves', 'de', 'fidélité', 'à', "l'Amérique", 'https://t.co/BffYjGwMxB']
# ['RT', '@bee_tuxedo', ':', "I'd", 'say', 'woot', ',', 'you', 'came', 'to', 'your', 'senses', ',', 'but', 'as', 'you', 'were', 'on', 'it', 'in', 'the', 'first', 'place', 'I', 'doubt', 'you', 'have', 'any', '.', 'https://t.co/UePVrOod…']
# ['RT', '@Reuters', ':', 'Trump', 'is', 'ordering', 'all', 'ambassadors', 'appointed', 'by', 'Obama', 'to', 'leave', 'their', 'post', 'by', 'inauguration', 'day', ':', '…']
# ['Trump-blog', '-', 'Aandeel', 'Toyota', 'daalt', 'na', 'tweet', 'Trump', 'https://t.co/xp1IUmWoS7', 'via', '@volkskrant']
# ['RT', '@Anna_LaPierre', ':', 'Let', 'Trump', 'see', 'what', 'he', 'wants', '.', 'I', 'see', 'this', '.', '#ObamaYears', '#MyAmerica', '@Potus', 'https://t.co/rE9GNFog2R']
# ['@nytimes', 'Lately', 'you', 'have', 'to', 'read', 'carefully', 'cause', 'you', "don't", 'know', 'if', 'these', 'news', 'come', 'from', 'a', 'country', 'run', 'by', 'extreme', 'islam', 'or', 'from', "trump's", 'land']
# ['6', 'of', '7', ':', '6', '.', 'Limit', 'media', 'access', '.', 'Trump', 'hasn', '’', 't', 'held', 'a', 'news', 'conference', 'since', 'July', '.', 'He', 'has', 'blocked', 'the', 'media', 'from', '...', 'https://t.co/AgwubP90ox']
# ['RT', '@DumpTrump22', ':', 'Our', 'Nation', 'Can', 'NOT', 'live', 'with', 'a', '#RussianTainted', 'Election', '.', 'Ex-CIA', 'operative', ':', 'We', 'may', 'need', 'a', 'new', 'vote', '-', '#TrumpLeaks', 'https://…']
# ["Trump's", 'Labor', 'Pick', 'First', 'Act', '.', 'https://t.co/jvY6h61olr']
# ['@HuffingtonPost', 'I', 'think', "it's", 'hilarious', 'that', 'the', 'people', 'who', 'voted', 'for', 'Trump', "that's", 'on', 'Obamacare', 'are', 'now', 'asking', '"', 'what', 'happened', '!', '?', '"', 'Oh', ',', 'you', 'knw', '!']
# ['Correct', 'https://t.co/CDsqYt2Iug']
# ['RT', '@POLITICOMag', ':', 'Trump', '’', 's', 'comments', 'have', 'been', 'met', 'with', 'support', 'or', 'silence', 'from', 'far', 'too', 'many', 'Republican', 'members', 'of', 'Congress', 'https://t.co/Preii…']
# ['@wikileaks', 'Small', 'potatoes', 'compared', 'to', 'obomba', 'giving', 'money', 'and', 'weapons', 'to', 'rogue', 'nuclear', 'APARTHEID', 'israel', '.', 'But', 'trump', 'will', 'do', '.', '#BDS']
# ['RT', '@Khanoisseur', ':', "Trump's", 'business', 'partner', '–', 'whose', 'office', 'was', 'in', 'Trump', 'Tower', '–', 'ran', 'a', 'sex', 'trafficking', 'ring', '@puppymnkey', '@SheWhoVotes', 'https://t.co/…']
# ['RT', '@EJNetwork', ':', 'Everything', 'Donald', '#Trump', 'has', 'ever', 'said', 'or', 'tweeted', '(', 'even', 'deleted', ')', 'is', 'now', 'online', 'in', 'this', 'useful', 'database', 'for', 'reporters', 'https', ':/', '…']
# ['Personal', 'point', 'of', 'view', ':', '"', 'Hacking', 'case', 'is', 'against', 'president', 'Trump', '!', '"', 'https://t.co/skx7snAFyf']
# ['RT', '@VicenteFoxQue', ':', 'Trump', 'may', 'ask', 'whoever', 'he', 'wants', ',', 'but', 'still', 'neither', 'myself', 'nor', 'Mexico', 'are', 'going', 'to', 'pay', 'for', 'his', 'racist', 'monument', '.', 'Another', 'pr', '…']
# ['RT', '@ava', ':', 'This', 'is', 'real', '.', 'This', 'is', 'disgraceful', '.', 'This', 'kind', 'of', 'thinking', 'requires', 'all', 'people', 'who', 'believe', 'in', 'dignity', 'and', 'justice', 'to', '…']
# ['Before', 'Briefing', ',', 'Trump', 'Continues', 'to', 'Disparage', 'Report', 'on', 'Russian', 'Hacking', '-', 'New', 'York', 'Times', 'https://t.co/wqf8G1YHwu']
# ['@mcspocky', 'and', 'ironically', 'Trump', "doesn't", 'pay', 'federal', 'taxes', 'and', "won't", 'contribute', 'a', 'dime', '-', 'what', 'a', 'con', 'man', '-', '#Swamp', 'is', 'fortified', 'further']
# ['RT', '@gomobel', ':', 'Brilliant', 'https://t.co/5CNFQM78Tu']
# ['RT', '@PrincessBravato', ':', '#TheResistance', 'this', 'is', 'why', 'trump', 'was', 'trying', 'to', 'distract', 'today', ',', 'he', 'knew', 'this', 'report', 'went', 'out', '!', '💥', '💥', '💥', 'https://t.co/kjeD…']
# ['@MindOfMarks', '@tomcoates', '@Serendipity33', 'No', 'Mark', ',', 'rooting', "'", 'against', 'Trump', ',', 'not', 'America', '...', "there's", 'a', 'difference', '...']
# ["Biden's", 'Last', 'Act', ':', 'House', ',', 'Senate', 'Gather', 'to', 'Make', "Trump's", 'Election', 'Final', 'Under', "Veep's", 'Gavel', '-', 'Breitbart', ',', 'https://t.co/AfeSMyNcUA']
# ['Yahoo', 'Finance', ',', 'Donald', 'Trump', 'and', 'the', 'Nigger', 'Navy', 'https://t.co/yIQ4jJafkP', 'https://t.co/z3wF7X5rkv']
# ['@Italy_Travel_', '@EnricoLetta', 'Gross', 'negligence', 'of', 'Democrats', 'have', 'a', 'compromised', 'candidate', 'like', 'Hillary', 'Clinton', '.', 'Whoever', 'won', 'against', 'Trump', '!']
# ['RT', '@JonRiley7', ':', 'Trump', 'claims', 'all', '17', 'US', 'intelligence', 'agencies', 'concluding', 'Russia', 'hacked', 'the', 'DNC', 'is', 'a', 'conspiracy', '?', 'That', 'red', '#MAGA', 'hat', 'i', '…']
# ['RT', '@wikileaks', ':', 'Result', 'of', 'CIA', 'officials', 'secretly', 'feeding', 'press', 'to', 'harm', 'Trump', ':', 'NBC', 'poll', ':', 'CIA', 'net', 'favorability', 'Trump', 'voters', ':', '+', '2', 'Clinton', 'voter', '…']
# ['@Independent', '@frankmcdonald60', 'If', 'he', 'leaves', 'the', 'USA', ',', 'Obama', 'could', 'drone-strike', 'Trump', 'for', 'being', 'a', 'Russian', 'agent', '...']
# ['RT', '@abdullahciftcib', ':', 'New', 'York', 'Times', ':', 'ABD', 'Dışişlerine', 'Trump', 'damgası', ':', "'", '20', "Ocak'ta", 'tüm', 'büyükelçilerin', 'görevine', 'son', 'verilecek', "'", 'https://t.co/4o4…']
# ['Après', 'Ford', 'et', 'General', 'Motors', ',', 'Toyota', 'se', 'fait', 'tancer', 'par', 'Donald', 'Trump', 'https://t.co/V2H2ieBvOY']
# ['Sources', ':', 'Trump', 'will', 'ask', 'Congress', ',', 'not', 'Mexico', ',', 'to', 'pay', 'for', 'border', 'wall', 'https://t.co/ibcZLToj0M']
# ['RT', '@TeaPainUSA', ':', "Trump's", 'caught', 'in', 'so', 'many', 'scandals', 'we', "can't", 'even', 'remember', 'what', 'his', 'latest', 'tweet', 'is', 'supposed', 'to', 'distract', 'us', 'from', '.']
# ['RT', '@mitchellvii', ':', 'WOW', ':', 'Trump', 'To', 'Fire', 'ALL', 'Obama-Ambassador', 'Appointments', 'On', 'Inauguration', 'Day', '-', 'https://t.co/ZYRg9FZRHB', 'https://t.co/vYH70j41xp']
# ['RT', '@thehill', ':', 'Trump', 'spokesman', ':', "There's", '"', 'deep', 'strategy', '"', 'behind', "Trump's", 'tweets', 'https://t.co/6XwNSAW2Qo', 'https://t.co/O7iF1LKkqR']
# ['RT', '@Salon', ':', 'Donald', 'Trump', 'has', 'really', 'warmed', 'to', 'Julian', 'Assange', ',', 'who', 'has', 'taken', 'on', "Trump's", 'CNN', 'hate', 'https://t.co/U350bThfjy']
# ['RT', '@yanpal7', ':', 'Should', 'be', 'an', 'interesting', 'meeting', '.', 'https://t.co/vpVStfCSX7']
# ['RT', '@jerryjamesstone', ':', 'Top', 'Obamacare', 'States', 'by', 'Enrollees', ':', 'FL', '-', '1,300', ',', '000', 'TX', '-', '776,000', 'NC', '-', '369,077', 'GA', '-', '352,000', 'PA', '-', '290,950', 'All', 'Trump', '…']
# ['Ex-CIA', 'director', 'James', 'Woolsey', 'quits', 'Trump', 'transition', 'team', 'https://t.co/2AOBuxqK5O', 'via', '@nbcnews']

# %%
#Counting Occurences 
with open('python.json', 'r') as f:
    count_all = Counter()
    for line in f:
        tweet = json.loads(line)
        terms = [term for term in tk.tokenize(tweet['text'])]
        count_all.update(terms)
    print (count_all.most_common(5))
# Out:
# [(':', 133), ('Trump', 104), ('RT', 96), ('.', 62), (',', 53)]

# %%
""" Since the above results are not interesting we need to remove stopwords: """
punctuation = list(string.punctuation)
stop = stopwords.words('english') + punctuation + ['RT', 'via', '…', 'I', "Trump's",'...','trump']

# %%
with open('python.json', 'r') as f:
    count_all = Counter()
    for line in f:
        tweet = json.loads(line)
        terms = [term for term in tk.tokenize(tweet['text']) if term not in stop]
        count_all.update(terms)
    print (count_all.most_common(10))
# Out:
# [('Trump', 104), ('Donald', 16), ('CIA', 8), ('Russian', 7), ('wall', 7), ('Mexico', 7), ('Obama', 7), ('pay', 7), ('#Trump', 7), ('ask', 6)]

# %%
with open('python.json', 'r') as f:
    count_all = Counter()
    for line in f:
        tweet = json.loads(line)
        terms = [term for term in tk.tokenize(tweet['text']) if term.startswith('#')]
        count_all.update(terms)
    print (count_all.most_common(10))
# Out:
# [('#Trump', 7), ('#MAGA', 3), ('#TheResistance', 3), ('#PutinsPuppet', 2), ('#Putin', 2), ('#Resist', 2), ('#Russians', 2), ('#IMPEACH', 2), ('#tcot', 2), ('#MyAmerica', 2)]
